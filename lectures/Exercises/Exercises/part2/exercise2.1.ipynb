# %% [markdown]
# # A)
# Use Pandas to import dataset 'X.csv'. Plot pairwise scatter plots of all the columns.

# %%
import pandas as pd
import seaborn as sns

X = pd.read_csv('./data_ex2.1-2.2/X.csv', delimiter=',')
X
# Out:
#       V1            V2          V3          V4            V5
# 1    386  14123.900514   23.195892   96.314697  16270.301197
# 2    281  12893.777551   36.380744  114.449670   8546.886578
# 3    455  14893.055887  -31.927240   65.843163  12164.390019
# 4    740   2727.835088  -21.751559  128.792865  16091.827762
# 5    335  13496.455515   13.467496  122.739135   8602.501560
# ..   ...           ...         ...         ...           ...
# 496  656   7762.087451  222.624221  409.614929  18618.637655
# 497  705  24833.647043  333.578263  357.070061  17923.930648
# 498  327   6017.764384  222.087455  223.415161   4990.584573
# 499  144   4465.045291  335.148946  371.383303   6694.805017
# 500   88   1723.968384  308.764976  444.082873  -3790.821817
#
# [500 rows x 5 columns]

# %%
sns.pairplot(X)
# Out:
# /home/andrea/miniconda3/envs/py3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/andrea/miniconda3/envs/py3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/andrea/miniconda3/envs/py3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
